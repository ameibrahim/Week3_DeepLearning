# %%
# %pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.24.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface_hub) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface_hub) (3.31.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface_hub) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface_hub) (1.5.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /Users/daryl/Library/Python/3.11/lib/python/site-packages (from huggingface_hub) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface_hub) (4.69.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/daryl/Library/Python/3.11/lib/python/site-packages (from huggingface_hub) (4.16.0)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.14.2)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.18)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import shutil
import zipfile

from huggingface_hub import hf_hub_download

REPO_ID = "ibrahimame13/animals"
FILENAME = "animals.zip"

DATASET_DIR = Path("./animals")
OUTPUT_DIR = Path("./")

# Delete the old extracted folder
if DATASET_DIR.exists():
    print(f"Deleting existing folder: {DATASET_DIR}")
    shutil.rmtree(DATASET_DIR)


print("Downloading dataset...")

zip_path = hf_hub_download(
    repo_id=REPO_ID,
    filename=FILENAME,
    repo_type="dataset",
)

print("Dataset downloaded.")
print("Extracting dataset...")


with zipfile.ZipFile(zip_path, "r") as zip_file:
    zip_file.extractall(OUTPUT_DIR)


print("Dataset extracted to:", OUTPUT_DIR.resolve())
# Out:
# Downloading dataset...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Dataset downloaded.
# Extracting dataset...
# Dataset extracted to: /Users/daryl/Documents/Github/Week3_DeepLearning
